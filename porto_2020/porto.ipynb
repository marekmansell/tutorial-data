# %%
from geopy.geocoders import Nominatim
import folium
from folium.plugins import HeatMap

# %%
data = [
    [41.143401, -8.620969, "red", "World of Discoveries", "trala"],
    [41.168639, -8.687571, "red", "World of Discoveries", "trala"],
    [41.176095, -8.692978, "red", "Matosinhos Beach", "trala"],
    [41.146887, -8.676956, "red", "Felgueiras Lighthouse", "trala"],
    [41.137301, -8.608911, "red", "Garden of Morro", "trala"],
    [41.152122, -8.606302, "blue", "Negra Café Baixa", "trala"],
    [41.147639, -8.666390, "blue", "Casa de Pasto da Palmeira", "trala"],
    [41.150027, -8.614751, "blue", "Nicolau Porto", "trala"],
    [41.147980, -8.665667, "blue", "Camélia - Brunch Garden", "trala"],
    [41.148840, -8.614264, "blue", "Restaurante Comme Ça", "trala"],
    [41.149169, -8.620466, "blue", "Pimenta Rosa", "trala"],
    [41.146885, -8.614518, "blue", "R. da Galeria de Paris", "trala"],
    [41.146607, -8.604836, "blue", "Cervejaria Brasão Coliseu", "trala"],
    [41.142977, -8.617422, "blue", "Hungry biker", "trala"],
    [41.149250, -8.612992, "blue", "BOA-BAO", "trala"],
    [41.148539, -8.615601, "blue", "Zenith - Brunch & Cocktails Bar", "trala"],
    [41.148086, -8.615886, "blue", "Moustache", "trala"],
]

# %%
m = folium.Map(
    location=[41.159648, -8.628175],
    zoom_start=13,
    tiles='OpenStreetMap'
)

for long, lat, color, title, desc in data:
    
    folium.Marker(
        radius=10,
        location=[long, lat],
        popup='<b>{}</b><br>{}<br>'.format(
            title,
            desc
        ),        
        fill=True,
        fill_opacity="1",
        icon=folium.Icon(icon='', prefix='fa', color=color),

        
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m._repr_html_()
# Out:
# '<div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>'
