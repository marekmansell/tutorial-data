# %% [markdown]
# # Vizualizácia výsledkov volieb na mieru
#
# Nielen štát nám v súčasnosti poskytuje veľké množstvo dát, ktoré novinári, marketéri či analytici využívajú svojej práci. Kľúčom k ich interpretácii môže byť napríklad aj vizualizácia na mape Slovenska. Práve to vieme dosiahnuť pomocou jazyka Python a knižnice Folium veľmi rýchlo a jednoducho.
#
# ## Komu pomôže vizualizácia?
# Vizualizácia dát môže využiť obrovské množstvo profesií. Zoberme si takého marketéra politickej strany - možno bude chcieť oslovovať voličov, u ktorých má vyššiu šancu na úspech na základe toho, aké strany strany volili v minulosti. V poslednom období sa taktiež hovorí viac aj o [dátových novinároch](https://dennikn.sk/blog/462494/co-robi-datovy-novinar-otestovali-vizualizacie-dat/), medzi ktorých patril aj Ján Kuciak. Tí využívajú vizualizáciu nie len na analýzu, ale aj priamo v článkoch. Kým v zahraničí je dátová žurnalistika štandard, na Slovensku sa iba pomaly rozbieha. A zabúdať netreba ani na osobné využitia, napríklad pre rodičov, ktorí práve vyberajú školu svojmu dieťaťu a chceli by si okolité školy spolu s ich hodnotením zobraziť prehľadne na mape.

# %% [markdown]
# ---

# %% [markdown]
# ## Knižnice
#
# Budeme používať knižnice:
# - Pandas (načítanie a úprava samotných dát)
# - Folium (vizualizácia na mape)
#
# Všetky knižnice sú inštalovateľné cez ``pip``, používame Python3.6 a novší.

# %%
import pandas as pd
import folium
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %% [markdown]
# ---

# %% [markdown]
# ## Načítanie datasetu

# %% [markdown]
# Samotný dataset stiahneme zo stránky [Štatistického úradu Slovenskej republiky](http://volby.statistics.sk/). Preklikáme sa cez podstránku *Údaje na stiahnutie* a zvolíme *VOĽBY DO NÁRODNEJ RADY SR* pre rok *2016*. Následne sa vypíše asi 20 rôznych datasetov, my vyberieme ``Výsledky hlasovania pre politické subjekty podľa obcí - PAR_2016_tab09.csv`` a súbor uložíme do adresára *datasets*.

# %%
data = pd.read_csv('datasets/PAR_2016_tab09.csv') # Načítanie datasetu do notebooku

# %% [markdown]
# Zobrazíme si dataset, aby sme vedeli, ako tabuľka s dátami vyzerá.

# %%
data.head(40) # Vypíše prvých 40 riadkov, aby sme si vedeli spraviť lepší prehľad o dátach
# Out:
#     Kód kraja               Kraj  Kód obvodu       Obvod  Kód okresu  \
# 0           1  Bratislavský kraj         101  Bratislava         101
# 1           1  Bratislavský kraj         101  Bratislava         101
# 2           1  Bratislavský kraj         101  Bratislava         101
# 3           1  Bratislavský kraj         101  Bratislava         101
# 4           1  Bratislavský kraj         101  Bratislava         101
# 5           1  Bratislavský kraj         101  Bratislava         101
# 6           1  Bratislavský kraj         101  Bratislava         101
# 7           1  Bratislavský kraj         101  Bratislava         101
# 8           1  Bratislavský kraj         101  Bratislava         101
# 9           1  Bratislavský kraj         101  Bratislava         101
# 10          1  Bratislavský kraj         101  Bratislava         101
# 11          1  Bratislavský kraj         101  Bratislava         101
# 12          1  Bratislavský kraj         101  Bratislava         101
# 13          1  Bratislavský kraj         101  Bratislava         101
# 14          1  Bratislavský kraj         101  Bratislava         101
# 15          1  Bratislavský kraj         101  Bratislava         101
# 16          1  Bratislavský kraj         101  Bratislava         101
# 17          1  Bratislavský kraj         101  Bratislava         101
# 18          1  Bratislavský kraj         101  Bratislava         101
# 19          1  Bratislavský kraj         101  Bratislava         101
# 20          1  Bratislavský kraj         101  Bratislava         101
# 21          1  Bratislavský kraj         101  Bratislava         101
# 22          1  Bratislavský kraj         101  Bratislava         101
# 23          1  Bratislavský kraj         101  Bratislava         102
# 24          1  Bratislavský kraj         101  Bratislava         102
# 25          1  Bratislavský kraj         101  Bratislava         102
# 26          1  Bratislavský kraj         101  Bratislava         102
# 27          1  Bratislavský kraj         101  Bratislava         102
# 28          1  Bratislavský kraj         101  Bratislava         102
# 29          1  Bratislavský kraj         101  Bratislava         102
# 30          1  Bratislavský kraj         101  Bratislava         102
# 31          1  Bratislavský kraj         101  Bratislava         102
# 32          1  Bratislavský kraj         101  Bratislava         102
# 33          1  Bratislavský kraj         101  Bratislava         102
# 34          1  Bratislavský kraj         101  Bratislava         102
# 35          1  Bratislavský kraj         101  Bratislava         102
# 36          1  Bratislavský kraj         101  Bratislava         102
# 37          1  Bratislavský kraj         101  Bratislava         102
# 38          1  Bratislavský kraj         101  Bratislava         102
# 39          1  Bratislavský kraj         101  Bratislava         102
#
#             Okres  Kód obce                               Obec  \
# 0    Bratislava I    528595           Bratislava - Staré Mesto
# 1    Bratislava I    528595           Bratislava - Staré Mesto
# 2    Bratislava I    528595           Bratislava - Staré Mesto
# 3    Bratislava I    528595           Bratislava - Staré Mesto
# 4    Bratislava I    528595           Bratislava - Staré Mesto
# 5    Bratislava I    528595           Bratislava - Staré Mesto
# 6    Bratislava I    528595           Bratislava - Staré Mesto
# 7    Bratislava I    528595           Bratislava - Staré Mesto
# 8    Bratislava I    528595           Bratislava - Staré Mesto
# 9    Bratislava I    528595           Bratislava - Staré Mesto
# 10   Bratislava I    528595           Bratislava - Staré Mesto
# 11   Bratislava I    528595           Bratislava - Staré Mesto
# 12   Bratislava I    528595           Bratislava - Staré Mesto
# 13   Bratislava I    528595           Bratislava - Staré Mesto
# 14   Bratislava I    528595           Bratislava - Staré Mesto
# 15   Bratislava I    528595           Bratislava - Staré Mesto
# 16   Bratislava I    528595           Bratislava - Staré Mesto
# 17   Bratislava I    528595           Bratislava - Staré Mesto
# 18   Bratislava I    528595           Bratislava - Staré Mesto
# 19   Bratislava I    528595           Bratislava - Staré Mesto
# 20   Bratislava I    528595           Bratislava - Staré Mesto
# 21   Bratislava I    528595           Bratislava - Staré Mesto
# 22   Bratislava I    528595           Bratislava - Staré Mesto
# 23  Bratislava II    529311  Bratislava - Podunajské Biskupice
# 24  Bratislava II    529311  Bratislava - Podunajské Biskupice
# 25  Bratislava II    529311  Bratislava - Podunajské Biskupice
# 26  Bratislava II    529311  Bratislava - Podunajské Biskupice
# 27  Bratislava II    529311  Bratislava - Podunajské Biskupice
# 28  Bratislava II    529311  Bratislava - Podunajské Biskupice
# 29  Bratislava II    529311  Bratislava - Podunajské Biskupice
# 30  Bratislava II    529311  Bratislava - Podunajské Biskupice
# 31  Bratislava II    529311  Bratislava - Podunajské Biskupice
# 32  Bratislava II    529311  Bratislava - Podunajské Biskupice
# 33  Bratislava II    529311  Bratislava - Podunajské Biskupice
# 34  Bratislava II    529311  Bratislava - Podunajské Biskupice
# 35  Bratislava II    529311  Bratislava - Podunajské Biskupice
# 36  Bratislava II    529311  Bratislava - Podunajské Biskupice
# 37  Bratislava II    529311  Bratislava - Podunajské Biskupice
# 38  Bratislava II    529311  Bratislava - Podunajské Biskupice
# 39  Bratislava II    529311  Bratislava - Podunajské Biskupice
#
#     Počet platných hlasov spolu  \
# 0                         26227
# 1                         26227
# 2                         26227
# 3                         26227
# 4                         26227
# 5                         26227
# 6                         26227
# 7                         26227
# 8                         26227
# 9                         26227
# 10                        26227
# 11                        26227
# 12                        26227
# 13                        26227
# 14                        26227
# 15                        26227
# 16                        26227
# 17                        26227
# 18                        26227
# 19                        26227
# 20                        26227
# 21                        26227
# 22                        26227
# 23                        11867
# 24                        11867
# 25                        11867
# 26                        11867
# 27                        11867
# 28                        11867
# 29                        11867
# 30                        11867
# 31                        11867
# 32                        11867
# 33                        11867
# 34                        11867
# 35                        11867
# 36                        11867
# 37                        11867
# 38                        11867
# 39                        11867
#
#                            Názov politického subjektu  \
# 0                                               #SIEŤ
# 1                                     DS - Ľudo Kaník
# 2                                                 KDH
# 3                      KOALÍCIA SPOLOČNE ZA SLOVENSKO
# 4                                                 KSS
# 5                                          MKDA-MKDSZ
# 6                                          MOST - HÍD
# 7   OBYČAJNÍ ĽUDIA a nezávislé osobnosti (OĽANO - ...
# 8          Odvaha - Veľká národná a proruská koalícia
# 9                                                  PD
# 10                                            SDKÚ-DS
# 11                                              SKOK!
# 12                          SME RODINA - Boris Kollár
# 13                                            SMER-SD
# 14                                            SMK-MKP
# 15                                                SNS
# 16                   STRANA MODERNÉHO SLOVENSKA (SMS)
# 17                                                SZS
# 18                                                SaS
# 19                                                TIP
# 20                                              VZDOR
# 21                                  ĽS Naše Slovensko
# 22                                              ŠANCA
# 23                                              #SIEŤ
# 24                                    DS - Ľudo Kaník
# 25                                                KDH
# 26                     KOALÍCIA SPOLOČNE ZA SLOVENSKO
# 27                                                KSS
# 28                                         MKDA-MKDSZ
# 29                                         MOST - HÍD
# 30  OBYČAJNÍ ĽUDIA a nezávislé osobnosti (OĽANO - ...
# 31         Odvaha - Veľká národná a proruská koalícia
# 32                                                 PD
# 33                                            SDKÚ-DS
# 34                                              SKOK!
# 35                          SME RODINA - Boris Kollár
# 36                                            SMER-SD
# 37                                            SMK-MKP
# 38                                                SNS
# 39                   STRANA MODERNÉHO SLOVENSKA (SMS)
#
#    Podiel platných hlasov v %  \
# 0                        7,22
# 1                        0,05
# 2                        5,28
# 3                        0,04
# 4                        0,20
# 5                        0,01
# 6                       12,42
# 7                       15,44
# 8                        0,08
# 9                        0,14
# 10                       0,50
# 11                       1,36
# 12                       3,83
# 13                      14,98
# 14                       0,62
# 15                       4,37
# 16                       0,06
# 17                       0,57
# 18                      29,60
# 19                       0,17
# 20                       0,05
# 21                       2,69
# 22                       0,22
# 23                       5,63
# 24                       0,03
# 25                       3,07
# 26                       0,10
# 27                       0,33
# 28                       0,07
# 29                      12,45
# 30                      12,17
# 31                       0,09
# 32                       0,20
# 33                       0,46
# 34                       1,50
# 35                       9,24
# 36                      18,91
# 37                       2,94
# 38                       5,45
# 39                       0,05
#
#    Podiel voličov, ktorí využili právo prednostného hlasovania v %  \
# 0                                               72,40
# 1                                               73,33
# 2                                               87,00
# 3                                               63,63
# 4                                               66,66
# 5                                               75,00
# 6                                               87,94
# 7                                               91,43
# 8                                               72,72
# 9                                               81,57
# 10                                              81,95
# 11                                              75,91
# 12                                              78,72
# 13                                              75,15
# 14                                              76,68
# 15                                              69,16
# 16                                              75,00
# 17                                              58,55
# 18                                              84,35
# 19                                              77,77
# 20                                              71,42
# 21                                              76,94
# 22                                              75,00
# 23                                              61,73
# 24                                             100,00
# 25                                              80,27
# 26                                              76,92
# 27                                              57,50
# 28                                              55,55
# 29                                              69,48
# 30                                              83,46
# 31                                              81,81
# 32                                              66,66
# 33                                              61,81
# 34                                              69,27
# 35                                              76,84
# 36                                              71,98
# 37                                              73,63
# 38                                              65,53
# 39                                              33,33
#
#     Počet platných hlasov  \
# 0                    1895
# 1                      15
# 2                    1385
# 3                      11
# 4                      54
# 5                       4
# 6                    3259
# 7                    4050
# 8                      22
# 9                      38
# 10                    133
# 11                    357
# 12                   1006
# 13                   3929
# 14                    163
# 15                   1148
# 16                     16
# 17                    152
# 18                   7764
# 19                     45
# 20                     14
# 21                    707
# 22                     60
# 23                    669
# 24                      4
# 25                    365
# 26                     13
# 27                     40
# 28                      9
# 29                   1478
# 30                   1445
# 31                     11
# 32                     24
# 33                     55
# 34                    179
# 35                   1097
# 36                   2245
# 37                    349
# 38                    647
# 39                      6
#
#     Počet voličov, ktorí využili právo prednostného hlasovania
# 0                                                1372
# 1                                                  11
# 2                                                1205
# 3                                                   7
# 4                                                  36
# 5                                                   3
# 6                                                2866
# 7                                                3703
# 8                                                  16
# 9                                                  31
# 10                                                109
# 11                                                271
# 12                                                792
# 13                                               2953
# 14                                                125
# 15                                                794
# 16                                                 12
# 17                                                 89
# 18                                               6549
# 19                                                 35
# 20                                                 10
# 21                                                544
# 22                                                 45
# 23                                                413
# 24                                                  4
# 25                                                293
# 26                                                 10
# 27                                                 23
# 28                                                  5
# 29                                               1027
# 30                                               1206
# 31                                                  9
# 32                                                 16
# 33                                                 34
# 34                                                124
# 35                                                843
# 36                                               1616
# 37                                                257
# 38                                                424
# 39                                                  2

# %% [markdown]
# Keď si dáta prezrieme, zitíme, že pre každú obec máme až 23 záznamov - jeden riadok pre výsledky každej politickej strany.

# %%
data.info() # Zobrazí názvy stĺpcov a ďalšie informácie
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44895 entries, 0 to 44894
# Data columns (total 14 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Kód kraja                                                        44895 non-null  int64
#  1   Kraj                                                             44895 non-null  object
#  2   Kód obvodu                                                       44895 non-null  int64
#  3   Obvod                                                            44895 non-null  object
#  4   Kód okresu                                                       44895 non-null  int64
#  5   Okres                                                            44895 non-null  object
#  6   Kód obce                                                         44895 non-null  int64
#  7   Obec                                                             44895 non-null  object
#  8   Počet platných hlasov spolu                                      44895 non-null  int64
#  9   Názov politického subjektu                                       44895 non-null  object
#  10  Podiel platných hlasov v %                                       44895 non-null  object
#  11  Podiel voličov, ktorí využili právo prednostného hlasovania v %  44895 non-null  object
#  12  Počet platných hlasov                                            44895 non-null  int64
#  13  Počet voličov, ktorí využili právo prednostného hlasovania       44895 non-null  int64
# dtypes: int64(7), object(7)
# memory usage: 4.8+ MB

# %%
# Vypíše počet politických strán
len(data['Názov politického subjektu'].unique())
# Out:
# 23

# %%
# Vypíše názvy politických strán
list(data['Názov politického subjektu'].unique())
# Out:
# ['#SIEŤ',
#  'DS - Ľudo Kaník',
#  'KDH',
#  'KOALÍCIA SPOLOČNE ZA SLOVENSKO',
#  'KSS',
#  'MKDA-MKDSZ',
#  'MOST - HÍD',
#  'OBYČAJNÍ ĽUDIA a nezávislé osobnosti (OĽANO - NOVA)',
#  'Odvaha - Veľká národná a proruská koalícia',
#  'PD',
#  'SDKÚ-DS',
#  'SKOK!',
#  'SME RODINA - Boris Kollár',
#  'SMER-SD',
#  'SMK-MKP',
#  'SNS',
#  'STRANA MODERNÉHO SLOVENSKA (SMS)',
#  'SZS',
#  'SaS',
#  'TIP',
#  'VZDOR',
#  'ĽS Naše Slovensko',
#  'ŠANCA']

# %% [markdown]
# ## Vyhľadanie obcí s najväčšou podporou pre danú politickú stranu
# Prvú vec, ktorú sa posnažíme nájsť v dátach, je, ktoré obce mali percentuálne najväčšiu podporu pre zadanú stranu a ktoré naopak najmenšiu.

# %% [markdown]
# Aby sme našli obce, kde má strana *SMER-SD* najväčšiu podporu, musíme si odfiltrovať ostatné záznamy pre iné politické strany - to spravíme podmienkou ``data['Názov politického subjektu'] == 'SMER-SD'``. Následne na usporiadanie hodnôt použijeme sunkciu  podľa ``sort_values`` - prvým parametrom je stĺpec, podľa ktorého chceme zoraďovať zázamy (v našom prípade ``Podiel platných hlasov v %``) druhý parameter určuje, že chceme zoraďovať zostupne (``ascending=False``). Keďže nám stačí iba prvých 5 záznamov, použijeme príkaz ``head(5)``.

# %%
# Vypíše 5 obcí s *najväčším* podielom hlasov pre stranu SMER-SD
data[data['Názov politického subjektu'] == 'SMER-SD'].sort_values('Podiel platných hlasov v %', ascending=False).head(5)
# Out:
#        Kód kraja                  Kraj  Kód obvodu            Obvod  \
# 42577          8          Košický kraj         804          Rožňava
# 13463          4       Nitriansky kraj         404       Nové Zámky
# 25613          6  Banskobystrický kraj         605      Veľký Krtíš
# 40598          8          Košický kraj         803       Michalovce
# 23945          6  Banskobystrický kraj         604  Rimavská Sobota
#
#        Kód okresu            Okres  Kód obce                 Obec  \
# 42577         808          Rožňava    526266               Slavec
# 13463         404       Nové Zámky    503029              Andovce
# 25613         610      Veľký Krtíš    516473  Veľká Ves nad Ipľom
# 40598         807       Michalovce    528633               Oborín
# 23945         609  Rimavská Sobota    514993               Janice
#
#        Počet platných hlasov spolu Názov politického subjektu  \
# 42577                          201                    SMER-SD
# 13463                          766                    SMER-SD
# 25613                          202                    SMER-SD
# 40598                          314                    SMER-SD
# 23945                           71                    SMER-SD
#
#       Podiel platných hlasov v %  \
# 42577                       9,95
# 13463                       9,92
# 25613                       9,90
# 40598                       9,87
# 23945                       9,85
#
#       Podiel voličov, ktorí využili právo prednostného hlasovania v %  \
# 42577                                              90,00
# 13463                                              80,26
# 25613                                              75,00
# 40598                                             100,00
# 23945                                             100,00
#
#        Počet platných hlasov  \
# 42577                     20
# 13463                     76
# 25613                     20
# 40598                     31
# 23945                      7
#
#        Počet voličov, ktorí využili právo prednostného hlasovania
# 42577                                                 18
# 13463                                                 61
# 25613                                                 15
# 40598                                                 31
# 23945                                                  7

# %% [markdown]
# Ak by sme chceli nájsť naopak obce s najmenšou podporou pre danú stranu, stačí zoradiť výsledko vzostupne ``ascending=True``.

# %%
# Vypíše 5 obcí s *najmenším* podielom hlasov pre stranu SMER-SD
data[data['Názov politického subjektu'] == 'SMER-SD'].sort_values('Podiel platných hlasov v %', ascending=True).head(5)
# Out:
#        Kód kraja                  Kraj  Kód obvodu            Obvod  \
# 23706          6  Banskobystrický kraj         604  Rimavská Sobota
# 24287          6  Banskobystrický kraj         604  Rimavská Sobota
# 23475          6  Banskobystrický kraj         604  Rimavská Sobota
# 24722          6  Banskobystrický kraj         604  Rimavská Sobota
# 40046          8          Košický kraj         803       Michalovce
#
#        Kód okresu            Okres  Kód obce               Obec  \
# 23706         609  Rimavská Sobota    514764  Gemerské Dechtáre
# 24287         609  Rimavská Sobota    515353           Radnovce
# 23475         609  Rimavská Sobota    514501              Barca
# 24722         609  Rimavská Sobota    515779             Vlkyňa
# 40046         807       Michalovce    528137               Beša
#
#        Počet platných hlasov spolu Názov politického subjektu  \
# 23706                          169                    SMER-SD
# 24287                          273                    SMER-SD
# 23475                          133                    SMER-SD
# 24722                          127                    SMER-SD
# 40046                          211                    SMER-SD
#
#       Podiel platných hlasov v %  \
# 23706                       0,59
# 24287                       0,73
# 23475                       0,75
# 24722                       0,78
# 40046                       0,94
#
#       Podiel voličov, ktorí využili právo prednostného hlasovania v %  \
# 23706                                             100,00
# 24287                                             100,00
# 23475                                             100,00
# 24722                                             100,00
# 40046                                              50,00
#
#        Počet platných hlasov  \
# 23706                      1
# 24287                      2
# 23475                      1
# 24722                      1
# 40046                      2
#
#        Počet voličov, ktorí využili právo prednostného hlasovania
# 23706                                                  1
# 24287                                                  2
# 23475                                                  1
# 24722                                                  1
# 40046                                                  1

# %% [markdown]
# ## Vykreslovanie na mape

# %%
# Vykreslenie čistej mapy vycentrovanej na Slovensko
m = folium.Map(
    location=[48.730556, 19.457222], # Určíme si koordináty stredu mapy
    zoom_start=8,  # Ako odzoomovaná má byť mapa
    tiles='OpenStreetMap'  # Ako podklad používame bezplatné OpenStreetMap mapy
)

m # Vykreslí mapu do Jupyter Notebooku
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Vykreslenie čistej mapy vycentrovanej na Slovensko
m = folium.Map(
    location=[48.730556, 19.457222], # Určíme si koordináty stredu mapy
    zoom_start=8,  # Ako odzoomovaná má byť mapa
    tiles='OpenStreetMap'  # Ako podklad používame bezplatné OpenStreetMap mapy
)

geolocator = Nominatim(user_agent="elections_2016")

for i in data[data['Názov politického subjektu'] == 'ĽS Naše Slovensko'].sort_values('Podiel platných hlasov v %', ascending=False).head(100).index:
    nazov_obce = data[data.index==i]['Obec'].to_string(index=False)

    location = geolocator.geocode(nazov_obce, country_codes='SK', timeout=20)
    folium.Marker(
        radius=1000,
        location=[location.latitude, location.longitude],
        popup='<b>{}<b>'.format(
            nazov_obce
        ),        
        icon=folium.Icon(icon='graduation-cap', prefix='fa', color="green"),
        fill=True,
        fill_opacity="1",

    ).add_to(m)
    
    print(i)

m # Vykreslí mapu do Jupyter Notebooku
# Out:
# 9289
# 26578
# 26957
# 4501
# 12078
# 32351
# 33407
# 36966
# 31943
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-230-7e5316df2205> in <module>
#      11     nazov_obce = data[data.index==i]['Obec'].to_string(index=False)
#      12
# ---> 13     location = geolocator.geocode(nazov_obce, country_codes='SK', timeout=20)
#      14     folium.Marker(
#      15         radius=1000,
#
# ~/Desktop/git/data-tutorials/elections_2016/venv/lib/python3.6/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded)
#     385
#     386         return self._parse_json(
# --> 387             self._call_geocoder(url, timeout=timeout), exactly_one
#     388         )
#     389
#
# ~/Desktop/git/data-tutorials/elections_2016/venv/lib/python3.6/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     353
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#     357             message = (
#
# /usr/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# /usr/lib/python3.6/urllib/request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# /usr/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /usr/lib/python3.6/urllib/request.py in https_open(self, req)
#    1359         def https_open(self, req):
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#    1363         https_request = AbstractHTTPHandler.do_request_
#
# /usr/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316             try:
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#    1320                 raise URLError(err)
#
# /usr/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1237                 encode_chunked=False):
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#    1241     def _send_request(self, method, url, body, headers, encode_chunked):
#
# /usr/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1283             # default charset of iso-8859-1.
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#    1287     def getresponse(self):
#
# /usr/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1232         else:
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#    1236     def request(self, method, url, body=None, headers={}, *,
#
# /usr/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1024         msg = b"\r\n".join(self._buffer)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#    1028         if message_body is not None:
#
# /usr/lib/python3.6/http/client.py in send(self, data)
#     962         if self.sock is None:
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#     966                 raise NotConnected()
#
# /usr/lib/python3.6/http/client.py in connect(self)
#    1398
#    1399             self.sock = self._context.wrap_socket(self.sock,
# -> 1400                                                   server_hostname=server_hostname)
#    1401             if not self._context.check_hostname and self._check_hostname:
#    1402                 try:
#
# /usr/lib/python3.6/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     405                          suppress_ragged_eofs=suppress_ragged_eofs,
#     406                          server_hostname=server_hostname,
# --> 407                          _context=self, _session=session)
#     408
#     409     def wrap_bio(self, incoming, outgoing, server_side=False,
#
# /usr/lib/python3.6/ssl.py in __init__(self, sock, keyfile, certfile, server_side, cert_reqs, ssl_version, ca_certs, do_handshake_on_connect, family, type, proto, fileno, suppress_ragged_eofs, npn_protocols, ciphers, server_hostname, _context, _session)
#     815                         # non-blocking
#     816                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 817                     self.do_handshake()
#     818
#     819             except (OSError, ValueError):
#
# /usr/lib/python3.6/ssl.py in do_handshake(self, block)
#    1075             if timeout == 0.0 and block:
#    1076                 self.settimeout(None)
# -> 1077             self._sslobj.do_handshake()
#    1078         finally:
#    1079             self.settimeout(timeout)
#
# /usr/lib/python3.6/ssl.py in do_handshake(self)
#     687     def do_handshake(self):
#     688         """Start the SSL/TLS handshake."""
# --> 689         self._sslobj.do_handshake()
#     690         if self.context.check_hostname:
#     691             if not self.server_hostname:
#
# KeyboardInterrupt:

# %% [markdown]
# ## GPS koordináty

# %%
gps_coordinates = pd.read_csv('datasets/gps_coordinates.csv') # Načítanie datasetu do notebooku

# %%
gps_coordinates = pd.DataFrame(columns=['Obec', 'Longitude', 'Latitude'])

# %%
# Vykreslenie čistej mapy vycentrovanej na Slovensko

geolocator = Nominatim(user_agent="elections_2016")
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

for i, nazov_obce in enumerate(list(data['Obec'].unique())):
   
    if not nazov_obce in list(gps_coordinates['Obec']):    
        location = geocode(nazov_obce, country_codes='SK', timeout=20)
        gps_coordinates = gps_coordinates.append({'Obec': nazov_obce, 'Longitude': location.longitude, 'Latitude': location.latitude}, ignore_index=True)

# %%
def get_latitude(city):
    return float(gps_coordinates[gps_coordinates['Obec'] == city].Latitude.to_string(index=None))

def get_longitude(city):
    return float(gps_coordinates[gps_coordinates['Obec'] == city].Longitude.to_string(index=None))

# %%
# gps_coordinates.to_csv("datasets/gps_coordinates.csv")

# %%
# gps_coordinates.to_csv("datasets/gps_coordinates.csv")

# %% [markdown]
# ---

# %%
list(gps_coordinates['Obec'])
# Out:
# ['Bratislava - Staré Mesto',
#  'Bratislava - Podunajské Biskupice',
#  'Bratislava - Ružinov',
#  'Bratislava - Vrakuňa',
#  'Bratislava - Nové Mesto',
#  'Bratislava - Rača',
#  'Bratislava - Vajnory',
#  'Bratislava - Devín',
#  'Bratislava - Devínska Nová Ves',
#  'Bratislava - Dúbravka',
#  'Bratislava - Karlova Ves',
#  'Bratislava - Lamač',
#  'Bratislava - Záhorská Bystrica',
#  'Bratislava - Čunovo',
#  'Bratislava - Jarovce',
#  'Bratislava - Petržalka',
#  'Bratislava - Rusovce',
#  'Borinka',
#  'Gajary',
#  'Jablonové',
#  'Jakubov',
#  'Kostolište',
#  'Kuchyňa',
#  'Láb',
#  'Lozorno',
#  'Malacky',
#  'Malé Leváre',
#  'Marianka',
#  'Pernek',
#  'Plavecké Podhradie']

# %%
float(gps_coordinates[gps_coordinates['Obec'] == 'Borinka'].Longitude.to_string(index=None))
# Out:
# 17.135971
